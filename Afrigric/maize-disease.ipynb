# %%
pip install --upgrade scikit-learn

# %%
pip install --upgrade imbalanced-learn

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import cv2
import os
from sklearn.model_selection import train_test_split

# ================================
# Load and preprocess dataset
# ================================
def load_dataset(directory, target_size=(224, 224)):
    datagen = ImageDataGenerator(rescale=1./255)
    generator = datagen.flow_from_directory(
        directory,
        target_size=target_size,
        batch_size=2000,  # Load large batch
        class_mode='categorical',
        shuffle=True
    )

    images, labels = next(generator)
    class_mapping = generator.class_indices
    inv_class_mapping = {v: k for k, v in class_mapping.items()}
    return images, labels, inv_class_mapping

# Load dataset
images, labels, inv_class_mapping = load_dataset("/kaggle/input/corn-or-maize-leaf-disease-dataset/data")

# Convert to class indices for SMOTE
class_indices = np.argmax(labels, axis=1)

# Train-test split
X_train, X_test, y_train_indices, y_test_indices = train_test_split(
    images, class_indices, test_size=0.05, stratify=class_indices, random_state=42
)

# Flatten images for SMOTE
n_samples, height, width, channels = X_train.shape
X_train_flat = X_train.reshape(n_samples, height * width * channels)

# Apply SMOTE
print("Before SMOTE - Class distribution:", np.bincount(y_train_indices))
smote = SMOTE(random_state=42)
X_train_balanced_flat, y_train_balanced = smote.fit_resample(X_train_flat, y_train_indices)
X_train_balanced = X_train_balanced_flat.reshape(-1, height, width, channels)

# One-hot encode labels
y_train_balanced = keras.utils.to_categorical(y_train_balanced, num_classes=len(inv_class_mapping))
y_test = keras.utils.to_categorical(y_test_indices, num_classes=len(inv_class_mapping))

print("After SMOTE - Class distribution:", np.bincount(np.argmax(y_train_balanced, axis=1)))

# ================================
# Build Model
# ================================
def create_model():
    base_model = keras.applications.MobileNetV2(
        input_shape=(224, 224, 3),
        include_top=False,
        weights='imagenet'
    )
    base_model.trainable = False

    inputs = keras.Input(shape=(224, 224, 3))
    x = base_model(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(len(inv_class_mapping), activation='softmax')(x)

    return keras.Model(inputs, outputs)

model = create_model()

model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ================================
# Train model
# ================================
history = model.fit(
    X_train_balanced, y_train_balanced,
    epochs=50,
    validation_data=(X_test, y_test),
    batch_size=16
)



# ================================
# Save the model
# ================================
model.save('maize_mobilenet.keras')
# Out:
# 2025-07-20 04:47:21.249616: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752986841.639886      86 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752986841.748102      86 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 4188 images belonging to 4 classes.
# Before SMOTE - Class distribution: [516 596 269 519]
# After SMOTE - Class distribution: [596 596 596 596]
# I0000 00:00:1752986888.757905      86 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1752986888.758687      86 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752986901.868045     151 service.cc:148] XLA service 0x7ea28c095330 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1752986901.869181     151 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1752986901.869199     151 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1752986902.752639     151 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   6/149 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.4099 - loss: 1.6029
# I0000 00:00:1752986907.682058     151 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 22s 61ms/step - accuracy: 0.7196 - loss: 0.6964 - val_accuracy: 0.8700 - val_loss: 0.2948
# Epoch 2/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9047 - loss: 0.2597 - val_accuracy: 0.9000 - val_loss: 0.2855
# Epoch 3/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9171 - loss: 0.2048 - val_accuracy: 0.8800 - val_loss: 0.3199
# Epoch 4/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9425 - loss: 0.1722 - val_accuracy: 0.8800 - val_loss: 0.2934
# Epoch 5/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9380 - loss: 0.1569 - val_accuracy: 0.9000 - val_loss: 0.3160
# Epoch 6/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9533 - loss: 0.1281 - val_accuracy: 0.8900 - val_loss: 0.3170
# Epoch 7/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9488 - loss: 0.1276 - val_accuracy: 0.8900 - val_loss: 0.3784
# Epoch 8/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9674 - loss: 0.0916 - val_accuracy: 0.9000 - val_loss: 0.4062
# Epoch 9/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9699 - loss: 0.0920 - val_accuracy: 0.9100 - val_loss: 0.3603
# Epoch 10/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9627 - loss: 0.0878 - val_accuracy: 0.9100 - val_loss: 0.3395
# Epoch 11/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9651 - loss: 0.0864 - val_accuracy: 0.9100 - val_loss: 0.3355
# Epoch 12/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9804 - loss: 0.0668 - val_accuracy: 0.8900 - val_loss: 0.3462
# Epoch 13/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9769 - loss: 0.0620 - val_accuracy: 0.9000 - val_loss: 0.3620
# Epoch 14/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9697 - loss: 0.0711 - val_accuracy: 0.8900 - val_loss: 0.3988
# Epoch 15/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9769 - loss: 0.0611 - val_accuracy: 0.9100 - val_loss: 0.4138
# Epoch 16/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9772 - loss: 0.0615 - val_accuracy: 0.9000 - val_loss: 0.4082
# Epoch 17/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9809 - loss: 0.0544 - val_accuracy: 0.9100 - val_loss: 0.5485
# Epoch 18/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9873 - loss: 0.0412 - val_accuracy: 0.8900 - val_loss: 0.5446
# Epoch 19/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9783 - loss: 0.0508 - val_accuracy: 0.9100 - val_loss: 0.4583
# Epoch 20/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9830 - loss: 0.0451 - val_accuracy: 0.9000 - val_loss: 0.4967
# Epoch 21/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9826 - loss: 0.0578 - val_accuracy: 0.9100 - val_loss: 0.5122
# Epoch 22/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9728 - loss: 0.0602 - val_accuracy: 0.9000 - val_loss: 0.4040
# Epoch 23/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9791 - loss: 0.0521 - val_accuracy: 0.9100 - val_loss: 0.5412
# Epoch 24/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9897 - loss: 0.0305 - val_accuracy: 0.9000 - val_loss: 0.5482
# Epoch 25/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9711 - loss: 0.0708 - val_accuracy: 0.9200 - val_loss: 0.5558
# Epoch 26/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9865 - loss: 0.0409 - val_accuracy: 0.9000 - val_loss: 0.5574
# Epoch 27/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9836 - loss: 0.0390 - val_accuracy: 0.9000 - val_loss: 0.5712
# Epoch 28/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9901 - loss: 0.0334 - val_accuracy: 0.9100 - val_loss: 0.5576
# Epoch 29/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9887 - loss: 0.0322 - val_accuracy: 0.9000 - val_loss: 0.5234
# Epoch 30/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9916 - loss: 0.0250 - val_accuracy: 0.9000 - val_loss: 0.5240
# Epoch 31/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9840 - loss: 0.0436 - val_accuracy: 0.9000 - val_loss: 0.6190
# Epoch 32/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9837 - loss: 0.0378 - val_accuracy: 0.9000 - val_loss: 0.5764
# Epoch 33/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9862 - loss: 0.0339 - val_accuracy: 0.9100 - val_loss: 0.5075
# Epoch 34/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9857 - loss: 0.0323 - val_accuracy: 0.9000 - val_loss: 0.6816
# Epoch 35/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9869 - loss: 0.0383 - val_accuracy: 0.9000 - val_loss: 0.6011
# Epoch 36/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9879 - loss: 0.0328 - val_accuracy: 0.8900 - val_loss: 0.5900
# Epoch 37/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9826 - loss: 0.0384 - val_accuracy: 0.9000 - val_loss: 0.5833
# Epoch 38/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9874 - loss: 0.0333 - val_accuracy: 0.9100 - val_loss: 0.6155
# Epoch 39/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9838 - loss: 0.0360 - val_accuracy: 0.9100 - val_loss: 0.6229
# Epoch 40/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9872 - loss: 0.0361 - val_accuracy: 0.9000 - val_loss: 0.6643
# Epoch 41/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9902 - loss: 0.0266 - val_accuracy: 0.9100 - val_loss: 0.6520
# Epoch 42/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9956 - loss: 0.0128 - val_accuracy: 0.9100 - val_loss: 0.6447
# Epoch 43/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9927 - loss: 0.0181 - val_accuracy: 0.9100 - val_loss: 0.6958
# Epoch 44/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9949 - loss: 0.0193 - val_accuracy: 0.9200 - val_loss: 0.5670
# Epoch 45/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9936 - loss: 0.0166 - val_accuracy: 0.8900 - val_loss: 0.6257
# Epoch 46/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9967 - loss: 0.0176 - val_accuracy: 0.9000 - val_loss: 0.5925
# Epoch 47/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9899 - loss: 0.0231 - val_accuracy: 0.9100 - val_loss: 0.6686
# Epoch 48/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9899 - loss: 0.0286 - val_accuracy: 0.9100 - val_loss: 0.6523
# Epoch 49/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9931 - loss: 0.0175 - val_accuracy: 0.9100 - val_loss: 0.5910
# Epoch 50/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9862 - loss: 0.0365 - val_accuracy: 0.9000 - val_loss: 0.5320

# %%
inv_class_mapping
# Out:
# {0: 'Blight', 1: 'Common_Rust', 2: 'Gray_Leaf_Spot', 3: 'Healthy'}
